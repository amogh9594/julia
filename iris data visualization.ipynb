# %%
using Pkg

# %%
Pkg.add("CSV")
# Out:
#     Updating registry at `C:\Users\amogh kawle\.julia\registries\General`
#     Updating git-repo `https://github.com/JuliaRegistries/General.git`
#    Resolving package versions...
#    Installed CSV ─ v0.9.10
#     Updating `C:\Users\amogh kawle\.julia\environments\v1.6\Project.toml`
#   [336ed68f] + CSV v0.9.10
#     Updating `C:\Users\amogh kawle\.julia\environments\v1.6\Manifest.toml`
#   [336ed68f] + CSV v0.9.10
#   [944b1d66] + CodecZlib v0.7.0
#   [48062228] + FilePathsBase v0.9.13
#   [91c51154] + SentinelArrays v1.3.8
#   [3bb67fe8] + TranscodingStreams v0.9.6
# Precompiling project...
#   ✓ TranscodingStreams
#   ✓ FilePathsBase
#   ✓ SentinelArrays
#   ✓ CodecZlib
#   ✓ CSV
#   5 dependencies successfully precompiled in 13 seconds (138 already precompiled)

# %%
Pkg.add("DataFrames")
# Out:
#     Updating registry at `C:\Users\amogh kawle\.julia\registries\General`
#     Updating git-repo `https://github.com/JuliaRegistries/General.git`
#    Resolving package versions...
#    Installed GLFW_jll ─ v3.3.5+1
#   No Changes to `C:\Users\amogh kawle\.julia\environments\v1.6\Project.toml`
#     Updating `C:\Users\amogh kawle\.julia\environments\v1.6\Manifest.toml`
#   [0656b61e] ↑ GLFW_jll v3.3.5+0 ⇒ v3.3.5+1
# Precompiling project...
#   ✓ GLFW_jll
#   ✓ GR_jll
#   ✓ GR
#   ✓ Plots
#   4 dependencies successfully precompiled in 56 seconds (139 already precompiled)

# %%
using CSV
using DataFrames

# %%
iris = DataFrame(CSV.File("Iris.csv"))
# Out:
# 150×6 DataFrame
#  Row │ Id     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Specie ⋯
#      │ Int64  Float64        Float64       Float64        Float64       String ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     1            5.1           3.5            1.4           0.2  Iris-s ⋯
#    2 │     2            4.9           3.0            1.4           0.2  Iris-s
#    3 │     3            4.7           3.2            1.3           0.2  Iris-s
#    4 │     4            4.6           3.1            1.5           0.2  Iris-s
#    5 │     5            5.0           3.6            1.4           0.2  Iris-s ⋯
#    6 │     6            5.4           3.9            1.7           0.4  Iris-s
#    7 │     7            4.6           3.4            1.4           0.3  Iris-s
#    8 │     8            5.0           3.4            1.5           0.2  Iris-s
# ...

# %%
typeof(iris)
# Out:
# DataFrame

# %%
names(iris)
# Out:
# 6-element Vector{String}:
#  "Id"
#  "SepalLengthCm"
#  "SepalWidthCm"
#  "PetalLengthCm"
#  "PetalWidthCm"
#  "Species"

# %%
size(iris)
# Out:
# (150, 6)

# %%
describe(iris)
# Out:
# 6×7 DataFrame
#  Row │ variable       mean     min          median  max             nmissing   ⋯
#      │ Symbol         Union…   Any          Union…  Any             Int64      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Id             75.5     1            75.5    150                    0   ⋯
#    2 │ SepalLengthCm  5.84333  4.3          5.8     7.9                    0
#    3 │ SepalWidthCm   3.054    2.0          3.0     4.4                    0
#    4 │ PetalLengthCm  3.75867  1.0          4.35    6.9                    0
#    5 │ PetalWidthCm   1.19867  0.1          1.3     2.5                    0   ⋯
#    6 │ Species                 Iris-setosa          Iris-virginica         0
#                                                                 1 column omitted

# %%
iris.Species
# Out:
# 150-element PooledArrays.PooledVector{String15, UInt32, Vector{UInt32}}:
#  "Iris-setosa"
#  "Iris-setosa"
#  "Iris-setosa"
#  "Iris-setosa"
#  "Iris-setosa"
#  "Iris-setosa"
#  "Iris-setosa"
#  "Iris-setosa"
#  "Iris-setosa"
#  "Iris-setosa"
#  "Iris-setosa"
#  "Iris-setosa"
#  "Iris-setosa"
#  ⋮
#  "Iris-virginica"
#  "Iris-virginica"
#  "Iris-virginica"
#  "Iris-virginica"
#  "Iris-virginica"
#  "Iris-virginica"
#  "Iris-virginica"
#  "Iris-virginica"
#  "Iris-virginica"
#  "Iris-virginica"
#  "Iris-virginica"
#  "Iris-virginica"

# %%
iris.PetalLengthCm
# Out:
# 150-element Vector{Float64}:
#  1.4
#  1.4
#  1.3
#  1.5
#  1.4
#  1.7
#  1.4
#  1.5
#  1.4
#  1.5
#  1.5
#  1.6
#  1.4
#  ⋮
#  4.8
#  5.4
#  5.6
#  5.1
#  5.1
#  5.9
#  5.7
#  5.2
#  5.0
#  5.2
#  5.4
#  5.1

# %%
iris[ :,3]
# Out:
# 150-element Vector{Float64}:
#  3.5
#  3.0
#  3.2
#  3.1
#  3.6
#  3.9
#  3.4
#  3.4
#  2.9
#  3.1
#  3.7
#  3.4
#  3.0
#  ⋮
#  3.0
#  3.1
#  3.1
#  3.1
#  2.7
#  3.2
#  3.3
#  3.0
#  2.5
#  3.0
#  3.4
#  3.0

# %%
Pkg.add("Plots")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\amogh kawle\.julia\environments\v1.6\Project.toml`
#   No Changes to `C:\Users\amogh kawle\.julia\environments\v1.6\Manifest.toml`

# %%
using Plots

# %%
p1 = plot(iris.PetalLengthCm)
p1

# %%
p2 = histogram(iris.PetalWidthCm)
p2

# %%
p3 = plot(iris.SepalLengthCm)
p3

# %%
p4 = histogram(iris.SepalWidthCm)
p4

# %%
plot(p1,p2,p3,p4, layout = (2,2), legend = false)
